# %%
# !mkdir /content/data

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
train_learning_rate_list = [] # Learning Rate
train_accuracy_list = [] # Accuracy
train_loss_cls_list = [] # Classification Loss
train_loss_bbox_list = [] # Bbox Regression Loss
train_loss_list = [] # Total Loss
train_loss_rpn_cls_list = [] # RPN Classification Loss
train_loss_rpn_bbox_list = [] # RPN Bbox Regression Loss

# %%
val_learning_rate_list = [] # Learning Rate
val_ap50_list = [] # AP50 (IOU50 적용시 Average Precision)
val_map_list = [] # mAP

# %%
import json

def getInformationsFromLogFile(filePath):
  with open(filePath) as file:
    oneJsonFile = json.load(file)

    for oneJsonData in oneJsonFile:
      if (oneJsonData["mode"] == 'train'):
        train_learning_rate_list.append(oneJsonData["lr"]) # Learning Rate
        train_accuracy_list.append(oneJsonData["acc"]) # Accuracy
        train_loss_cls_list.append(oneJsonData["loss_cls"]) # Classification Loss
        train_loss_bbox_list.append(oneJsonData["loss_bbox"]) # Bbox Regression Loss
        train_loss_list.append(oneJsonData["loss"]) # Total Loss
        train_loss_rpn_cls_list.append(oneJsonData["loss_rpn_cls"]) # RPN Classification Loss
        train_loss_rpn_bbox_list.append(oneJsonData["loss_rpn_bbox"]) # RPN Bbox Regression Loss

      elif (oneJsonData["mode"] == 'val'):
        val_learning_rate_list.append(oneJsonData['lr']) # Learning Rate
        val_ap50_list.append(oneJsonData['AP50']) # AP50 (IOU50 적용시 Average Precision)
        val_map_list.append(oneJsonData['mAP']) # mAP

    return train_learning_rate_list, train_accuracy_list, train_loss_cls_list, train_loss_bbox_list, train_loss_list, train_loss_rpn_cls_list, train_loss_rpn_bbox_list, val_learning_rate_list, val_ap50_list, val_map_list

# %%
getInformationsFromLogFile("/content/data/arranged_None_log.json")
# Out:
# ([0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
#   0.0025,
# ...

# %%
len(train_accuracy_list)
# Out:
# 678

# %%
len(val_map_list)
# Out:
# 9

# %%
fig = plt.figure(figsize=(7, 7), facecolor='linen')

ax1 = fig.add_subplot(1, 1, 1) # 행 1개, 열 1개 중 첫번째 오브젝트 선택
ax1.plot(train_learning_rate_list)
ax1.set_title("Learning rate trend during model training", fontsize=15)
ax1.set_xlabel("example", fontsize=10)
ax1.set_ylabel("train_learning_rate", fontsize=10)
# Out:
# Text(0, 0.5, 'train_learning_rate')

# %%
fig = plt.figure(figsize=(7, 7), facecolor='linen')

ax1 = fig.add_subplot(1, 1, 1) # 행 1개, 열 1개 중 첫번째 오브젝트 선택
ax1.plot(train_accuracy_list)
ax1.set_title("train_accuracy", fontsize=10)
# Out:
# Text(0.5, 1.0, 'train_accuracy')

# %%
fig = plt.figure(figsize=(7, 7), facecolor='linen')

ax1 = fig.add_subplot(1, 1, 1) # 행 1개, 열 1개 중 첫번째 오브젝트 선택
ax1.plot(train_loss_cls_list)
ax1.set_title("train_loss_cls", fontsize=10)
# Out:
# Text(0.5, 1.0, 'train_loss_cls')

# %%
fig = plt.figure(figsize=(7, 7), facecolor='linen')

ax1 = fig.add_subplot(1, 1, 1) # 행 1개, 열 1개 중 첫번째 오브젝트 선택
ax1.plot(train_loss_bbox_list)
ax1.set_title("train_loss_bbox", fontsize=10)
# Out:
# Text(0.5, 1.0, 'train_loss_bbox')

# %%
fig = plt.figure(figsize=(7, 7), facecolor='linen')

ax1 = fig.add_subplot(1, 1, 1) # 행 1개, 열 1개 중 첫번째 오브젝트 선택
ax1.plot(train_loss_list)
ax1.set_title("train_loss", fontsize=10)
# Out:
# Text(0.5, 1.0, 'train_loss')

# %%
fig = plt.figure(figsize=(7, 7), facecolor='linen')

ax1 = fig.add_subplot(1, 1, 1) # 행 1개, 열 1개 중 첫번째 오브젝트 선택
ax1.plot(train_loss_rpn_cls_list)
ax1.set_title("train_loss_rpn_cls", fontsize=10)
# Out:
# Text(0.5, 1.0, 'train_loss_rpn_cls')

# %%
fig = plt.figure(figsize=(7, 7), facecolor='linen')

ax1 = fig.add_subplot(1, 1, 1) # 행 1개, 열 1개 중 첫번째 오브젝트 선택
ax1.plot(train_loss_rpn_bbox_list)
ax1.set_title("train_loss_rpn_bbox", fontsize=10)
# Out:
# Text(0.5, 1.0, 'train_loss_rpn_bbox')

# %%
fig = plt.figure(figsize=(7, 7), facecolor='linen')

ax1 = fig.add_subplot(1, 1, 1) # 행 1개, 열 1개 중 첫번째 오브젝트 선택
ax1.plot(val_learning_rate_list)
ax1.set_title("val_learning_rate", fontsize=10)
# Out:
# Text(0.5, 1.0, 'val_learning_rate')

# %%
fig = plt.figure(figsize=(7, 7), facecolor='linen')

ax1 = fig.add_subplot(1, 1, 1) # 행 1개, 열 1개 중 첫번째 오브젝트 선택
ax1.plot(val_ap50_list)
ax1.set_title("val_AP50", fontsize=10)
# Out:
# Text(0.5, 1.0, 'val_AP50')

# %%
fig = plt.figure(figsize=(7, 7), facecolor='linen')

ax1 = fig.add_subplot(1, 1, 1) # 행 1개, 열 1개 중 첫번째 오브젝트 선택
ax1.plot(val_map_list)
ax1.set_title("val_mAP", fontsize=10)
# Out:
# Text(0.5, 1.0, 'val_mAP')
